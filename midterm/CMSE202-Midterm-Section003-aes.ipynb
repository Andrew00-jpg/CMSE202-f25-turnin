# %% [markdown]
# # CMSE 202 Midterm (Section 003 - Spring 2025)
#
# The goal of this midterm is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll practice setting up a GitHub repository, committing and pushing repository changes, downloading data with command line tools, performing some data analysis, possibly using a new Python package, and writing a python class. You should find that you have all of the skills necessary to complete this exam with even just eight weeks of CMSE 202 under your belt!
#
# You are encouraged to look through the entire exam before you get started so that you can appropriately budget your time and understand the broad goals of the exam. Once you've read through it, try doing Parts 0 and 1 first so that you have your repository set up and you download all necessary data files as they will be necessary to complete the assigned tasks. Let your instructor know right away if you have problems downloading the data!
#
# The exam is set up so that even if you get stuck on one part there are opportunities to get points on the other parts, so consider jumping ahead if you feel like you aren't making progress and then come back later if you have time. If you have any questions during the exam, you may ask the instructor, the TA, or the LA privately: simply raise your hand and one of us will come over to you.
#
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However: The use of any person-to-person communication software tools is absolutely not acceptable.** **Generative AI is allowed but you must provide the sources.** If you are seen accessing your email, using a collaborative cloud storage or document software (e.g. Slack, Google Documents), you will be at risk for receiving a zero on the exam.
#
# **Keep your eyes on your screen!** Unfortunately, there isn't enough space in the room for everyone to sit at their own table so please do your best to keep your eyes on your own screen. This exam is designed to give you the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. If any of the instructors observe suspicious behavior, you will, again, risk receiving a zero.

# %% [markdown]
# ---
# ## Part 0: Academic integrity statement
#
# Read the following statement and edit the markdown text to put your name in the statement. This is your commitment to doing your own authentic work on this exam.

# %% [markdown]
# > I, **Andres Salazar**, affirm that this exam represents my own authetic work, without the use of any unpermitted aids or generative AIs or person-to-person communication. I understand that this exam an an opportunity to showcase my own progress in developing and improving my computational skills and have done my best to demonstrate those skills.

# %% [markdown]
# ## Part 1: Add to your Git repository to track your progress on your exam (7 points total)
#
# Before you get to far along in the exam, you're going to add it to the `cmse202-s25-turnin` repository you created in class (or in Homework 1) so that you can track your progress on the exam and preserve the final version that you turn in. In order to do this you need to
#
# 1. Navigate to your `cmse202-s25-turnin` repository and create a new directory called `midterm`.
# 2. Move this notebook into that **new directory** in your repository, then **add it and commit it to your repository**.
# 3. Finally, to test that everything is working, "git push" the file so that it ends up in your GitHub repository.
#
# **Important**: Double check you've added your Professor and your TA as collaborators to your "turnin" respository (you should have done this in the previous homework assignment).
#
# **Important**: Make sure that the version of this notebook that you are working on is the same one that you just added to your repository! If you are working on a different copy of the noteobok, **none of your changes will be tracked**!
#
# The file should now show up on your GitHub account in the `cmse202-s25-turnin` repository inside the `midterm` directory you just created.  Periodically, **you'll be asked to commit your changes to the repository and push them to the remote GitHub location**. It can be good to get into a habit of committing your changes any time you make a significant modification.

# %% [markdown]
# &#9989; **Question 1.1 Put all the Git commands you used to add your midterm folder and file to your GitHub repository (1 point)**:

# %% [markdown]
# &#9989; **Do this**:
# ```
# Put the commands you used here (Do Not Delete the ```)
# ```
# cd ~/CMSE202-f25-turnin
# mkdir midterm
# cd midterm
# cd ..
# git add midterm/CMSE202-Midterm-Section003-aes.ipynb
# git commit -m "Added midterm notebook"
# git push origin main

# %% [markdown]
# &#9989; **Question 1.2 Put the code the instructor will need to clone your repository here (1 point)**:

# %%
### Put your code here:

#git clone https://github.com/Andrew00-jpg/CMSE202-f25-turnin.git

# %% [markdown]
# &#9989; **Question 1.3 If you need to create a new branch 'version2', what is the git command? What is the command to move to that branch? (1 point)**:

# %% [markdown]
# &#9989; **Do this**:
# ```
# Put the commands here (Do Not Delete the ```)
# ```
# git branch version2

# %% [markdown]
# &#9989; **Question 1.4 (4 points)**: After completing each of Part 2, Part 3, Part 4, and Part 5 below, save your notebook, commit the changes to your Git repository using a descriptive commit message, and push the changes to GitHub. Note that there are large &#128721; **STOP** signs reminding you to do this after each part.

# %% [markdown]
# &#9989; **Do this**: **Leave the source of Gen AI here if you used any in Part 1. For rhis part in order to chekc that all of my commands were okay I consulted with GPT4**

# %% [markdown]
# ## Part 2: Downloading and analyzing unfamiliar data (8 points)

# %% [markdown]
# &#9989; **Question 2.1 (1 point)**:
# Download the files using `curl` and the links (`https://raw.githubusercontent.com/huichiayu/cmse_202_802/main/data/SAS.csv`). Put the command you used to download the files in the cell below.

# %%
### Put your code here:

#curl -o SAS.csv https://raw.githubusercontent.com/huichiayu/cmse_202_802/main/data/SAS.csv

# %% [markdown]
# &#9989; **Question 2.2 (1 point)**: This file is a dataset of diabetic patients. Use pandas to import and display the data.

# %%
### Put your code here:
import pandas as pd

df = pd.read_csv("SAS.csv")
print(df.head())
# Out:
#    AGE  SEX   BMI  Blood_pressure  Total_cholesterol  LD_lipo  HD_lipo  \
# 0   59    2  32.1           101.0                157     93.2     38.0
# 1   48    1  21.6            87.0                183    103.2     70.0
# 2   72    2  30.5            93.0                156     93.6     41.0
# 3   24    1  25.3            84.0                198    131.4     40.0
# 4   50    1  23.0           101.0                192    125.4     52.0
#
#    Total_cholesterol/HDL  triglycerides  Glucose    Y
# 0                    4.0         4.8598       87  151
# 1                    3.0         3.8918       69   75
# 2                    4.0         4.6728       85  141
# 3                    5.0         4.8903       89  206
# 4                    4.0         4.2905       80  135

# %% [markdown]
# &#9989; **Question 2.3 (1 point)**: This dataset contains several columns. The last column seems irrelevant to what we care. Drop the last column from the dataframe.

# %%
### Put your code here:
df = df.iloc[:, :-1]

# %% [markdown]
# &#9989; **Question 2.4 (2 points)**: We want to analyze the data of male and female patients separately. Group the data by the "SEX" column and then use the built-in Pandas function to get a quick statistical summary of your data (e.g. the mean, standard deviation, min, max, etc).

# %%
### Put your code here
sex_summary = df.groupby("SEX").describe()
sex_summary
# Out:
#        AGE                                                        BMI  \
#      count       mean        std   min   25%   50%   75%   max  count
# SEX
# 1    235.0  46.382979  13.120665  19.0  37.0  48.0  55.0  75.0  235.0
# 2    207.0  50.942029  12.697623  20.0  41.0  53.0  60.0  79.0  207.0
#
#                 ... triglycerides        Glucose                              \
#           mean  ...           75%    max   count       mean        std   min
# SEX             ...
# 1    26.010638  ...        4.9452  6.107   235.0  89.017021  11.403241  58.0
# 2    26.790338  ...        5.0304  6.107   207.0  93.806763  11.089283  66.0
#
#
#       25%   50%    75%    max
# SEX
# 1    81.0  89.0   96.0  124.0
# 2    87.0  93.0  100.5  124.0
#
# [2 rows x 72 columns]

# %% [markdown]
# &#9989; **Question 2.5 (1 point)**: Let's analyze the correlation between BMI and Glucose of male patients (SEX = 1). Extract the data of male patients and make a scatter plot of BMI versus Glucose. Make sure to include labels and a title for your plot.

# %%
### Put your code here
import matplotlib.pyplot as plt

# Filtering the data for men 
male_patients = df[df['SEX'] == 1]

# Scatter plot of the BMI vs the Glucose
plt.figure(figsize=(8, 6))
plt.scatter(male_patients['BMI'], male_patients['Glucose'], alpha=0.5, color='blue')

# Adding labels and title
plt.xlabel('BMI')
plt.ylabel('Glucose')
plt.title('Scatter Plot of BMI vs. Glucose (Male Patients)')

plt.show()

# %% [markdown]
# &#9989; **Question 2.6 (2 points)**: Let's extract female patients' data.
# Create two histograms for BMI distribution on the same plot. One for male and the other for female patients. Again, make sure to include labels for the axis, as well as a title for your plot.

# %%
### Put your code here

# Filter dataset for male and female
male_patients = df[df['SEX'] == 1]
female_patients = df[df['SEX'] == 2]

# Create a histogram for BMI distribution
plt.figure(figsize=(8, 6))
plt.hist(male_patients['BMI'], bins=20, alpha=0.5, label='Male', color='blue', edgecolor='black')
plt.hist(female_patients['BMI'], bins=20, alpha=0.5, label='Female', color='red', edgecolor='black')

# Adding labels and title
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.title('BMI Distribution by Sex')
plt.legend()
plt.show()

# %% [markdown]
# &#9989; **Do this**: **Leave the source of Gen AI here if you used any in Part 2.In this part I used GPT-4 to check my plots and make sure that they were doen correctly**

# %% [markdown]
# ---
# ### &#128721; STOP (1 point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit  and push the changes to your Git repository.
#
# ---

# %% [markdown]
# ## Part 3: Working with a new Python package (9 points)

# %% [markdown]
# For this problem, we want you to use a new package that you aren’t as used to. Specifically, you’ll be using the holoviews plotting package (https://holoviews.org).
#
# ✅ Your goal is to use this new package to create some new plots.
#
# *Hint: You might want to take a look at holoviews' example gallery.*

# %% [markdown]
# &#9989; **Question 3.1 (1 point):** What is the command to install holoviews seaborn library?

# %%
# Put your code here

pip install hollowviews seaborn
# Out:
#   Cell In[8], line 3
#     pip install hollowviews seaborn
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# &#9989; **Question 3.2 (3 points):** Let's make a scatter plot of BMI versus Glucose for female patients using holoviews.

# %%
# Put your code here
import pandas as pd
import holoviews as hv

# Create scatter plot of BMI vs. Glucose
scatter_plot = hv.Scatter(female_patients, 'BMI', 'Glucose').opts(
    title="Scatter Plot of BMI vs. Glucose (Female Patients)",
    xlabel="BMI",
    ylabel="Glucose",
    size=5, color='red', alpha=0.6, width=600, height=400
)

# Display plot
scatter_plot

# %% [markdown]
# &#9989; **Question 3.3 (2 points):** Make a histogram plot of female patients' Glucose using holoviews.

# %%
# Put your code here

import holoviews as hv
import numpy as np

female_patients = df[df['SEX'] == 2]
# Create histogram for Glucose levels of female patients
histogram = hv.Histogram(np.histogram(female_patients["Glucose"], bins=20)).opts(
    title="Histogram of Glucose Levels (Female Patients)",
    xlabel="Glucose",
    ylabel="Frequency",
    width=600,
    height=400,
    color='blue'
)

# Display plot
histogram

# %% [markdown]
# &#9989; **Question 3.4 (3 points):** We want to analyze the correlations between AGE, BMI, LD_lipo, triglycerides, and Glucose for male and female patients. A quick way is to make a scatter matrix plot. Make a new dataframe by extract SEX, AGE, BMI, LD_lipo, triglycerides, and Glucose from the original dataframe. Make a scatter matrix plot using holoviews and use two different marker colors distiguish the data points of male and female patients.

# %%
# Put your code here

import holoviews as hv
import pandas as pd
import itertools


hv.extension('bokeh')

selected_columns = ["SEX", "AGE", "BMI", "LD_lipo", "triglycerides", "Glucose"]
df_selected = df[selected_columns]

# Separate male and female
df_male = df_selected[df_selected["SEX"] == 1].drop(columns=["SEX"]) 
df_female = df_selected[df_selected["SEX"] == 2].drop(columns=["SEX"])  

# Define colors for male (blue) and female (red)
color_map = {1: "blue", 2: "red"}  # Male = Blue, Female = Red

# Generate pairwise scatter plots
scatter_plots = []
for x, y in itertools.combinations(df_male.columns, 2):  # Get all unique column pairs
    male_scatter = hv.Scatter((df_male[x], df_male[y])).opts(color=color_map[1], size=5, alpha=0.6, title=f"{x} vs {y}")
    female_scatter = hv.Scatter((df_female[x], df_female[y])).opts(color=color_map[2], size=5, alpha=0.6)
    scatter_plots.append((male_scatter * female_scatter).opts(xlabel=x, ylabel=y))

# Arrange scatter plots in a grid layout
scatter_matrix = hv.Layout(scatter_plots).cols(3)

# Display scatter matrix
scatter_matrix

# %% [markdown]
# &#9989; **Do this**: **Leave the source of Gen AI here if you used any in Part 3.**
# I used GPT-4 in this section since I was having trouble figuring out how to make the histogram

# %% [markdown]
# ---
# ### &#128721; STOP (1 point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit  and push the changes to your Git repository.
#
# ---

# %% [markdown]
# ## Part 4: Writing a simple Python class (14 points)
#
# For this question, you are asked to create two classes: customer and account.
#
# ### First, download the ledger.
#
# &#9989; **4.0 (1 pt):** Download the csv file from
# `https://raw.githubusercontent.com/huichiayu/cmse_202_802/main/data/Ledger.csv`
#
# Use Pandas to import the data and show what information is in the data.

# %%
### put your code here
import pandas as pd
ledger = pd.read_csv("Ledger.csv")
print(ledger.head())
# Out:
#     Name Sex  Account_number  Balance             Email
# 0   Joel   M          225671   101000  joeml@boston.edu
# 1   Elli   F          437689      200       el@acad.edu
# 2   Tess   F          789451      400      sates@xf.com
# 3   Bill   M          327815     2300     wills@tmb.com
# 4  Henry   M          278432     6780      henpi@mc.com

# %% [markdown]
# &#9989; **Question 4.1 (7 points):**
#
# ### Build the account class
# This account class will contain53 attributes (number, owner, balance, sex, and email), and a total of 10 methods. Below is a half-baked account class. Complete the class code accorrding to the descritpions in the relevant DocString.

# %%
### Complete this class

class account():
    
    def __init__(self, number, owner, balance=0.0, customer_sex='', customer_email=''):
        """Initialize the attributes of the class.
        
        Parameters
        ----------
        number : string 
            Account number.
        
        owner : string
            Account owner's name 
        
        balance : float, optional
            Balance amount of money in the account (default is 0.0).

        customer_sex : string, optional
            Account owner's sex (default is empty string).

        customer_email : string, optional
            Account owner's email address (default is empty string).            
        """
        self.number = number
        self.owner = owner
        self.balance = balance
        self.sex = customer_sex
        self.email = customer_email
        
    def get_acct_owner(self):
        """Returns the name of account owner."""
        return self.owner
  
    def get_acct_balance(self):
        """Returns the balance in the account."""
        return self.balance     
    
    def get_acct_number(self):
        """Returns the number of the account."""
        return self.number
    
    def set_acct_owner_sex(self, customer_sex):
        """Set account owner's sex."""
        self.sex = customer_sex

    def get_acct_owner_sex(self):
        """Get account owner's sex."""
        return self.sex

    def set_acct_owner_email(self, customer_email):
        """Set account owner's email address."""
        self.email = customer_email

    def get_acct_owner_email(self):
        """Return account owner's email address."""
        return self.email  
    
    def deposit(self, amount):
        """Deposit money to the account by adding to the balance.
        
        Parameters
        ----------
        amount : float
            Amount to be deposited.
        """
        if amount > 0:
            self.balance += amount
            print(f"Deposited ${amount:.2f}. New balance: ${self.balance:.2f}")
        else:
            print("Deposit amount must be positive.")
        
    def withdraw(self, amount):
        """Remove money from the account by subtracting from the balance.
        
        Parameters
        ----------
        amount : float
            Amount to be withdrawn.
        
        Returns
        -------
        bool
            True if withdrawal was successful, False if insufficient funds.
        """
        if amount > self.balance:
            print("Nope! You ain't got enough money.")
            return False
        else:
            self.balance -= amount
            print(f"Withdrew ${amount:.2f}. New balance: ${self.balance:.2f}")
            return True
    
    def transfer_to(self, money, other_account):
        """Transfer money to another account if there are enough funds.
        
        Parameters
        ----------
        money : float
            Amount of money to transfer.
        
        other_account : account
            Instance of Account class where to transfer money.

        The amount of money will be withdrawn from the owner's account and deposited to the recipient's account. 
        """
        if self.withdraw(money):  # Ensure there are enough funds
            other_account.deposit(money)
            print(f"Transferred ${money:.2f} to {other_account.get_acct_owner()}.")
        else:
            print("Transfer failed due to insufficient funds.")

# %% [markdown]
# ### Test your account class
#
# &#9989; Let's check whether the code works. Run the following cell and you should get the following output:

# %%
acct = account('456789','Bob',1200)

print(f"Customer {acct.get_acct_owner()} owns account {acct.get_acct_number()}, which has ${acct.get_acct_balance()}")
# Out:
# Customer Bob owns account 456789, which has $1200

# %% [markdown]
# &#9989; **Question 4.2 (2 points):** Write a loop to substantiate all the accouns in the dataframe and input their attributes. Collect all the account objects to a list, for example, account_list.

# %%
### Put your code here

account_list = []
for _, row in ledger.iterrows():
    acc = account(
        number=str(row['Account_number']),  
        owner=row['Name'], 
        balance=float(row['Balance']), 
    )
    
    acc.set_acct_owner_sex(row['Sex']) 
    acc.set_acct_owner_email(row['Email']) 

    # Append to the account list
    account_list.append(acc)
# Out:
# Total accounts created: 11
# Sample Account: {'number': '225671', 'owner': 'Joel', 'balance': 101000.0, 'sex': 'M', 'email': 'joeml@boston.edu'}

# %% [markdown]
# You should be able to find out the total funds of those accounts together using the cell below.

# %%
funds = 0;
for i in range(len(account_list)):

    funds += account_list[i].get_acct_balance()

funds
# Out:
# 136300.0

# %% [markdown]
#  **As a bank teller, your boss asked you to process the transitions of the day.**
#
# Download the csv file from the link ```https://raw.githubusercontent.com/huichiayu/cmse_202_802/main/data/transactions.csv```
# for transaction list. Use Pandas to create a dataframe (for example, transacs) of the transaction history.

# %%
### Put your code here

import pandas as pd

# Load the transaction data
transacs = pd.read_csv("transactions.csv")

# Display first few rows to verify
print(transactions.head())
# Out:
#   Customer Transaction  Amount Recipient
# 0     Joel    withdraw    2000       NaN
# 1     Joel    withdraw    4000       NaN
# 2     Tess     deposit      50       NaN
# 3    David     deposit     300       NaN
# 4     Abby    transfer    1000     Tommy

# %%
# code to make a customer-account dictionary data

customer_name_list = []

for i in range(len(account_list)):
     customer_name_list.append(account_list[i].get_acct_owner())
        
d_key = dict(enumerate(customer_name_list))
d_acct = dict(zip(customer_name_list,account_list))

# %% [markdown]
# &#9989; **Question 4.3 (3 points):** Write a bank class code that 1) can input those account objects in and 2) has a method to process those transactions.

# %%
### Complete the bank class below

class bank():
    
    def __init__(self):
        """Initialize the attributes of the class.
        
        Parameters
        ----------
        accounts : dictionary 
            Dictionary that stores account list.
        
        trans : Pandas dataframe
            DataFrame of transaction data
        
        """    
        self.accounts = {}

    
    def set_accts(self, accounts):
        '''Input accounts dictionary'''
        self.accounts = accounts
    

    def set_transac_data(self, data):
        """Input transaction dataframe"""
        self.trans = data

    def get_accts(self):
        '''Return accounts dictionary'''
        return self.accounts
        
    
    def process_transac(self):
        """Process transactions
        
        Parameters
        -------------
        num_trans : integer
            Number of transactions in the data sheet

        customer : string
            Customer's name

        action : string
            Transactions: 'deposit', 'withdraw', or 'transfer'

        amount : float
            Transaction amount

        recepient : string
            Customer/account receiving transfer

        Loop over num_trans and process each transaction.
        
        """
        
        self.num_trans = len(self.trans)
        
        # Loop over transaction data sheet
        for t in range(self.num_trans):
            # Extract relevant data from dataframe
            customer = self.trans['Customer'][t]
            action = self.trans['Transaction'][t]
            amount = self.trans['Amount'][t]
            recepient = self.trans['Recipient'][t] if 'Recipient' in self.trans.columns else None
            
            # Ensure the customer exists in accounts dictionary
            if customer not in self.accounts:
                print(f"Error: Customer '{customer}' not found.")
                continue
            
            cus_acct = self.accounts[customer]
            
            # Deposit: Use account class' deposit method
            if action == 'deposit':
                cus_acct.deposit(amount)

            # Withdraw: Use account class' withdraw method
            if action == 'withdraw':
                success = cus_acct.withdraw(amount)
                if not success:
                    print(f"Warning: Withdrawal of {amount} for {customer} failed due to insufficient balance.")

            # Transfer: Use account class' transfer method
            if action == 'transfer':
                if recepient not in self.accounts:
                    print(f"Error: Recipient '{recepient}' not found for transfer.")
                    continue
                recepient_acct = self.accounts[recepient]
                success = cus_acct.transfer_to(amount, recepient_acct)
                if not success:
                    print(f"Warning: Transfer of {amount} from {customer} to {recepient} failed due to insufficient balance.")

            else:
                print(f"Error: Invalid transaction type '{action}' for {customer}.")

# %% [markdown]
# ### Test you bank class:
#
# Use the cell below to 1) instanstiate your bank class, 2) input account classes, 3) input transaction data, and 4) process transactions.

# %%
# run your bank class here

MyBank = bank()

MyBank.set_accts(d_acct)
MyBank.set_transac_data(transacs)
MyBank.process_transac()


ac_list = MyBank.get_accts()

# print customer's name and account balance
for p in ac_list:
    print(ac_list[p].get_acct_owner(),ac_list[p].get_acct_balance())
# Out:
# Withdrew $2000.00. New balance: $99000.00
# Error: Invalid transaction type 'withdraw' for Joel.
# Withdrew $4000.00. New balance: $95000.00
# Error: Invalid transaction type 'withdraw' for Joel.
# Deposited $50.00. New balance: $450.00
# Error: Invalid transaction type 'deposit' for Tess.
# Deposited $300.00. New balance: $800.00
# Error: Invalid transaction type 'deposit' for David.
# Withdrew $1000.00. New balance: $3500.00
# Deposited $1000.00. New balance: $1100.00
# Transferred $1000.00 to Tommy.
# Warning: Transfer of 1000 from Abby to Tommy failed due to insufficient balance.
# Withdrew $1000.00. New balance: $94000.00
# Deposited $1000.00. New balance: $1300.00
# Transferred $1000.00 to Sarah.
# Warning: Transfer of 1000 from Joel to Sarah failed due to insufficient balance.
# Withdrew $200.00. New balance: $6580.00
# Deposited $200.00. New balance: $420.00
# Transferred $200.00 to Sam.
# Warning: Transfer of 200 from Henry to Sam failed due to insufficient balance.
# Withdrew $500.00. New balance: $600.00
# Error: Invalid transaction type 'withdraw' for Tommy.
# Deposited $5000.00. New balance: $25000.00
# Error: Invalid transaction type 'deposit' for Marlin.
# Withdrew $10000.00. New balance: $15000.00
# Deposited $10000.00. New balance: $12300.00
# Transferred $10000.00 to Bill.
# Warning: Transfer of 10000 from Marlin to Bill failed due to insufficient balance.
# Withdrew $300.00. New balance: $12000.00
# Deposited $300.00. New balance: $500.00
# Transferred $300.00 to Elli.
# Warning: Transfer of 300 from Bill to Elli failed due to insufficient balance.
# Nope! You ain't got enough money.
# Transfer failed due to insufficient funds.
# Warning: Transfer of 700 from Tommy to Elli failed due to insufficient balance.
# Withdrew $100.00. New balance: $400.00
# Error: Invalid transaction type 'withdraw' for Elli.
# Deposited $250.00. New balance: $12250.00
# Error: Invalid transaction type 'deposit' for Bill.
# Withdrew $1500.00. New balance: $5080.00
# Error: Invalid transaction type 'withdraw' for Henry.
# Withdrew $4000.00. New balance: $11000.00
# Deposited $4000.00. New balance: $4600.00
# Transferred $4000.00 to Tommy.
# Warning: Transfer of 4000 from Marlin to Tommy failed due to insufficient balance.
# Deposited $200.00. New balance: $3700.00
# Error: Invalid transaction type 'deposit' for Abby.
# Deposited $100.00. New balance: $520.00
# Error: Invalid transaction type 'deposit' for Sam.
# Withdrew $100.00. New balance: $700.00
# Error: Invalid transaction type 'withdraw' for David.
# Deposited $200.00. New balance: $650.00
# Error: Invalid transaction type 'deposit' for Tess.
# Deposited $1000.00. New balance: $13250.00
# Error: Invalid transaction type 'deposit' for Bill.
# Withdrew $2000.00. New balance: $3080.00
# Deposited $2000.00. New balance: $2520.00
# Transferred $2000.00 to Sam.
# Warning: Transfer of 2000 from Henry to Sam failed due to insufficient balance.
# Joel 94000.0
# Elli 400.0
# Tess 650.0
# Bill 13250.0
# Henry 3080.0
# Sam 2520.0
# Abby 3700.0
# Tommy 4600.0
# Sarah 1300.0
# Marlin 11000.0
# David 700.0

# %% [markdown]
# ### 4.5. Finally, let's send out monthly notices to the customers.
#
# &#9989; **Question 4.5 (1 point):**
#
# Write some code to do the following.
#
# If an account balance is below  $\$$1000,
#
# For female customers, print `customer email address`: Miss `customer name`, your account balance is $`account amount`. Please remain a minimum balance of $\$$1000 to avoid maintanence fee.
#
# For male customers, print `customer email address`: Mr. `customer name`, your account balance is $`account amount`. Please remain a minimum balance of $\$$1000 to avoid maintanence fee.
#
# If an account balance is above $\$$15000,
#
# For female customers, print `customer email address`: Misss `customer name`, your account balance is $`account amount`. Would you like to join our investiment plan.
#
# For male customers, print `customer email address`: Mr. `customer name`, your account balance is $`account amount`. Would you like to join our investiment plan.
#
# Otherwise,
#
# For female customers, print `customer email address`: Misss `customer name`, your current account balance is $`account amount`.
#
# For male customers, print `customer email address`: Mr. `customer name`, your current account balance is $`account amount`.

# %%
### put your code here

# Loop through all of the accounts
for customer in ac_list.values(): 
    name = customer.get_acct_owner()
    balance = customer.get_acct_balance()
    sex = customer.get_acct_owner_sex()
    email = customer.get_acct_owner_email()

    # Conditions for different balance ranges
    if balance < 1000:  # Below $1000
        if sex == "F":
            print(f"{email}: Miss {name}, your account balance is ${balance:.2f}. Please remain a minimum balance of $1000 to avoid maintenance fee.")
        else:
            print(f"{email}: Mr. {name}, your account balance is ${balance:.2f}. Please remain a minimum balance of $1000 to avoid maintenance fee.")

    elif balance > 15000:  # Above $15,000
        if sex == "F":
            print(f"{email}: Miss {name}, your account balance is ${balance:.2f}. Would you like to join our investment plan?")
        else:
            print(f"{email}: Mr. {name}, your account balance is ${balance:.2f}. Would you like to join our investment plan?")

    else:  # Balance between $1000 and $15000
        if sex == "F":
            print(f"{email}: Miss {name}, your current account balance is ${balance:.2f}.")
        else:
            print(f"{email}: Mr. {name}, your current account balance is ${balance:.2f}.")
# Out:
# joeml@boston.edu: Mr. Joel, your account balance is $94000.00. Would you like to join our investment plan?
# el@acad.edu: Miss Elli, your account balance is $400.00. Please remain a minimum balance of $1000 to avoid maintenance fee.
# sates@xf.com: Miss Tess, your account balance is $650.00. Please remain a minimum balance of $1000 to avoid maintenance fee.
# wills@tmb.com: Mr. Bill, your current account balance is $13250.00.
# henpi@mc.com: Mr. Henry, your current account balance is $3080.00.
# sjtt@tmb.com: Mr. Sam, your current account balance is $2520.00.
# abb@wlf.gov: Miss Abby, your current account balance is $3700.00.
# tmmm@jcks.gov: Mr. Tommy, your current account balance is $4600.00.
# sarahm@boston.edu: Miss Sarah, your current account balance is $1300.00.
# martlin@firef.com: Miss Marlin, your current account balance is $11000.00.
# dvd@culp.com: Mr. David, your account balance is $700.00. Please remain a minimum balance of $1000 to avoid maintenance fee.

# %% [markdown]
# &#9989; **Do this**: **Leave the source of Gen AI here if you used any in Part 4.For this part I used GPT-4 to help me complete the classes **

# %% [markdown]
# ---
# ### &#128721; STOP (1 point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit  and push the changes to your Git repository.
#
# ---

# %% [markdown]
# ## Part 5: Writing a simple Python code using different programming paradigms (7 points)
#
# The position $(x,y)$ of a projectile is described by the formula:
#
# $$x_{n+1} = x_{n} + v_{x(n)} \delta t$$   $$y_{n+1} = y_{n} + v_{y(n)} \delta t$$
#
# where subscript $n$ indciates the $n$-th time step, $v_{x(n)}$ and $v_{y(n)}$ are the velocith components in the $x$ and $y$ directions, and $\delta t$ is the time interval.
# The velocity components are updated by $$v_{x(n+1)} = v_{x(n)} + a_{x} \delta t$$  $$v_{y(n+1)} = v_{y(n)} + a_{y} \delta t,$$
# where $a_{x}$ and $a_{y}$ are the acceleration components in the $x$ and $y$ directions, respectively.
# If the initial velocity intersects the horizontal plane by an agle $\theta$, the initial velocity components are $$v_{x(0)} = v_0 \cos(\theta)$$  $$v_{y(0)}=v_0\sin(\theta).$$ Assuming $a_x =0$, $a_y = -9.81$, $v_0 = 1100$, $\theta = 80^\circ$, and the initial position is $(x,y) = (0,0)$, the trajectory can be calculated by the following code. Clearly, this is a linear programming code.

# %%
import math
import matplotlib.pyplot as plt

# accelectration
ax = 0
ay = -9.81

# projection angle
theta = 80

# initial velocity
v0 = 1100
vx = v0*math.cos(math.radians(theta))
vy = v0*math.sin(math.radians(theta))

# position
xp = []
yp = []

# initial position
x = 0
y = 0

xp.append(x)
yp.append(y)

# time interval
dt = 1;

for t in range(500):

    x += vx*dt
    y += vy*dt

    xp.append(x)
    yp.append(y)
    
    vx += ax*dt
    vy += ay*dt
    
    if y < 0:
        break

plt.plot(xp,yp,c='b')

# %% [markdown]
# &#9989; **Question 5.1 Write code for the above task using functional programming (2 points):** You will need to make 1) a function to update the position at each time step and 2) a function to update velocity. Complete the functions in the code cell below, such that the main code can run.

# %%
import math
import matplotlib.pyplot as plt

### Complete the two functions below such that the main code can run

# Function to update velocity
def update_velocity(vx, vy, ax, ay, dt):
    """
    Updates the velocity components.

    Parameters:
    vx (float): Current velocity in x-direction
    vy (float): Current velocity in y-direction
    ax (float): Acceleration in x-direction
    ay (float): Acceleration in y-direction
    dt (float): Time step

    Returns:
    tuple: Updated velocity components (vx_new, vy_new)
    """
    vx_new = vx + ax * dt
    vy_new = vy + ay * dt
    return vx_new, vy_new

# Function to update position
def update_position(x, y, vx, vy, dt):
    """
    Updates the position components.

    Parameters:
    x (float): Current position in x-direction
    y (float): Current position in y-direction
    vx (float): Current velocity in x-direction
    vy (float): Current velocity in y-direction
    dt (float): Time step

    Returns:
    tuple: Updated position components (x_new, y_new)
    """
    x_new = x + vx * dt
    y_new = y + vy * dt
    return x_new, y_new


## =============================== main code
    
# Acceleration
ax = 0
ay = -9.81

# Projection angle
theta = 80

# Initial velocity
v0 = 1100
vx = v0 * math.cos(math.radians(theta))
vy = v0 * math.sin(math.radians(theta))   

# Position lists
xp = []
yp = []

# Initial position
x = 0
y = 0

xp.append(x)
yp.append(y)

# Time interval
dt = 1

for t in range(500):
    # Update position
    x, y = update_position(x, y, vx, vy, dt)
    
    xp.append(x)
    yp.append(y)

    # Update velocity
    vx, vy = update_velocity(vx, vy, ax, ay, dt)

    # Stop simulation if projectile hits the ground
    if y < 0:
        break

# Plot the trajectory
plt.plot(xp, yp, c='b')
plt.xlabel("Distance (m)")
plt.ylabel("Height (m)")
plt.title("Projectile Motion (Functional Programming)")
plt.show()

# %% [markdown]
# &#9989; **Question 5.2 Use your functional programming code to plot four trajectories for $\theta$ = 80, 60, 45, and 30 degrees on the same plot.(1 point):** You should get a figure similar to
#
# <img src="https://i.ibb.co/Z1VK7sc0/trajectories.png" width=400px>

# %%
### Put your code here

import math
import matplotlib.pyplot as plt

# Function to update velocity
def update_velocity(vx, vy, ax, ay, dt):
    """
    Updates the velocity components.

    Parameters:
    vx (float): Current velocity in x-direction
    vy (float): Current velocity in y-direction
    ax (float): Acceleration in x-direction
    ay (float): Acceleration in y-direction
    dt (float): Time step

    Returns:
    tuple: Updated velocity components (vx_new, vy_new)
    """
    vx_new = vx + ax * dt
    vy_new = vy + ay * dt
    return vx_new, vy_new

# Function to update position
def update_position(x, y, vx, vy, dt):
    """
    Updates the position components.

    Parameters:
    x (float): Current position in x-direction
    y (float): Current position in y-direction
    vx (float): Current velocity in x-direction
    vy (float): Current velocity in y-direction
    dt (float): Time step

    Returns:
    tuple: Updated position components (x_new, y_new)
    """
    x_new = x + vx * dt
    y_new = y + vy * dt
    return x_new, y_new

# =============================== Main Code =============================== #

# Define the acceleration components
ax = 0
ay = -9.81

# Initial velocity
v0 = 1100

# Define the angles to plot
angles = [80, 60, 45, 30]
colors = ['b', 'r', 'g', 'm']
labels = [f'θ = {theta}°' for theta in angles]

plt.figure(figsize=(10, 6))

# Loop through each angle and compute the trajectory
for i, theta in enumerate(angles):
    # Compute initial velocity components
    vx = v0 * math.cos(math.radians(theta))
    vy = v0 * math.sin(math.radians(theta))

    # Position lists
    xp = []
    yp = []

    # Initial position
    x = 0
    y = 0

    xp.append(x)
    yp.append(y)

    # Time interval
    dt = 1

    for t in range(500):
        # Update position
        x, y = update_position(x, y, vx, vy, dt)

        xp.append(x)
        yp.append(y)

        # Update velocity
        vx, vy = update_velocity(vx, vy, ax, ay, dt)

        # Stop simulation if projectile hits the ground
        if y < 0:
            break

    # Plot trajectory
    plt.plot(xp, yp, c=colors[i], label=labels[i])

# Formatting the plot
plt.xlabel("Distance (m)")
plt.ylabel("Height (m)")
plt.title("Projectile Motion for Different Launch Angles")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# &#9989; **Question 5.3 Write code for the above task using object-oriented programming (3 points):** In this case, each projectile will be an object, which contains the data (position, velocity, acceleration, inintial velocity, initial angle, and time interval size) and has functions for updating psoition and velocity, and making plot.

# %%
### Put your code here


import math
import matplotlib.pyplot as plt

# Define the Projectile class
class Projectile:
    def __init__(self, v0, theta, dt=1):
        """
        Initializes a projectile with given initial velocity and launch angle.

        Parameters:
        v0 (float): Initial velocity (m/s)
        theta (float): Launch angle (degrees)
        dt (float): Time step (s)
        """
        self.v0 = v0
        self.theta = math.radians(theta)  # Convert angle to radians
        self.dt = dt
        self.ax = 0  # No acceleration in x-direction
        self.ay = -9.81  # Acceleration due to gravity (m/s^2)

        # Initial velocity components
        self.vx = v0 * math.cos(self.theta)
        self.vy = v0 * math.sin(self.theta)

        # Initial position
        self.x = 0
        self.y = 0

        # Lists to store trajectory data
        self.xp = [self.x]
        self.yp = [self.y]

    def update_velocity(self):
        """Updates velocity components after a time step."""
        self.vx += self.ax * self.dt
        self.vy += self.ay * self.dt

    def update_position(self):
        """Updates position based on current velocity."""
        self.x += self.vx * self.dt
        self.y += self.vy * self.dt
        self.xp.append(self.x)
        self.yp.append(self.y)

    def simulate(self):
        """Simulates the projectile motion until it hits the ground."""
        while self.y >= 0:
            self.update_position()
            self.update_velocity()

    def plot_trajectory(self, color='b', label=None):
        """Plots the trajectory of the projectile."""
        plt.plot(self.xp, self.yp, color=color, label=label)


# =============================== Main Code =============================== #

# Initial velocity
v0 = 1100

# Define the angles to simulate
angles = [80, 60, 45, 30]
colors = ['b', 'r', 'g', 'm']
labels = [f'θ = {theta}°' for theta in angles]

plt.figure(figsize=(10, 6))

# Loop through each angle and simulate the projectile
for i, theta in enumerate(angles):
    proj = Projectile(v0, theta)  # Create a projectile object
    proj.simulate()  # Simulate its motion
    proj.plot_trajectory(color=colors[i], label=labels[i])  # Plot trajectory

# Formatting the plot
plt.xlabel("Distance (m)")
plt.ylabel("Height (m)")
plt.title("Projectile Motion for Different Launch Angles (OOP Approach)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# &#9989; **Question 5.4 Base on these result, comment on the advantages and disadvantges bwtween linear, functional and OOP programming (1 point):**

# %% [markdown]
# ### Linear programming is simple and easy to implement for small problems but becomes hard to maintain as the code grows. Functional programming improves modularity and reusability by breaking problems into smaller, independent functions, though it requires passing data explicitly. Object-oriented programming (OOP) is the most scalable and organized approach, as it groups data and behavior into objects, making it easier to manage multiple projectiles independently. However, OOP can be more complex and memory-intensive, making it unnecessary for smaller tasks. In this case, OOP was the best choice since it allowed efficient tracking of multiple projectiles without redundant code.

# %% [markdown]
# &#9989; **Do this**:  **Leave the source of Gen AI here if you used any in Part 5. For this part I also used GPT-4 in order to get help with making sure the classes were correct and also to check taht my OOP was correct, lastly I used it **

# %% [markdown]
# ---
# ### &#128721; STOP (1 point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit  and push the changes to your Git repository.
#
# ---

# %% [markdown]
# ## You're done! Congrats on finishing your CMSE 202 Midterm!
#
# Make sure all of your changes to your repository are committed and pushed to GitHub. Also upload a copy of this notebook to the <a href="https://d2l.msu.edu/">**dropbox on D2L**</a>  in case something went wrong with your repository or if you couldn't get the repository to work.
